# %%
from utils import *
import sys, os
from compare_locations import compare_locations

datadir = "./data"
# preprocessed already, with
#parallel -k python3 ../preprocessing.py ./precis_whitelist.json {1} 1::: [0-7]*json
#python3 ../preprocessing.py ./precis_whitelist.json 1-pixel-25-02-2021_21-16-46.json

# %%
#similarity_collection_vs_all(collection, index = 5, method = 'Average')

# %%
# Generate a matrix (list of lists) for a collection (etaj)
# [point_index, index_of_closest_pt, dist_to_closest_pt, index_diff, dist_2_best_neighbor]
def test_allvsall(collection, simil_method, method = 'Average'):
    lc = len(collection)
    #arr = [[0]*lc]*lc - nu merge!
    arr = [[0 for i in range(lc)] for j in range(lc)]
    for l in range(0, lc):
        for c in range(0, l):
            arr[l][c] = compare_locations(collection[l], collection[c], simil_method = simil_method, method = 'Max')
            arr[c][l] = arr[l][c]
        arr[l][l] = 1 # max 

   # print("#pt minpt mindist diff dist2nbr")
    listp = []
    for l in range(0, lc):
        mindist = min(arr[l])
        index_of_min = arr[l].index(mindist)
        diff = diff_modulo(l, arr[l].index(mindist), lc)
        distl=arr[l][(l-1+lc)%lc]
        distr=arr[l][(l+1)%lc]

        #print(l, index_of_min, mindist, diff, min(distl, distr))
        listp.append([l, index_of_min, mindist, diff, min(distl, distr)])
    return listp

# %%
#Pixel
etaje_0_p = ["p0_0-pixel-04-03-2021_15-32-38.json",
"p0_1-pixel-25-02-2021_21-16-46.json",
"p0_2-pixel-25-02-2021_16-27-45.json",
"p0_3-pixel-04-03-2021_16-18-50.json",
"p0_4-pixel-04-03-2021_16-43-50.json",
"p0_5-pixel-04-03-2021_17-11-32.json",
"p0_6-pixel-17-03-2021_12-52-29.json",
"p0_7-pixel-17-03-2021_13-14-36.json"]

etaje_1_p = ["p0_0-pixel-04-03-2021_15-32-38.json",
"p1_1-pixel-25-02-2021_21-16-46.json",
"p1_2-pixel-25-02-2021_16-27-45.json",
"p1_3-pixel-04-03-2021_16-18-50.json",
"p1_4-pixel-04-03-2021_16-43-50.json",
"p1_5-pixel-04-03-2021_17-11-32.json",
"p1_6-pixel-17-03-2021_12-52-29.json",
"p1_7-pixel-17-03-2021_13-14-36.json"]

etaje_2_p = ["p2_0-pixel-04-03-2021_15-32-38.json",
"p2_1-pixel-25-02-2021_21-16-46.json",
"p2_2-pixel-25-02-2021_16-27-45.json",
"p2_3-pixel-04-03-2021_16-18-50.json",
"p2_4-pixel-04-03-2021_16-43-50.json",
"p2_5-pixel-04-03-2021_17-11-32.json",
"p2_6-pixel-17-03-2021_12-52-29.json",
"p2_7-pixel-17-03-2021_13-14-36.json"]

etaje_3_p = ["p3_0-pixel-04-03-2021_15-32-38.json",
"p3_1-pixel-25-02-2021_21-16-46.json",
"p3_2-pixel-25-02-2021_16-27-45.json",
"p3_3-pixel-04-03-2021_16-18-50.json",
"p3_4-pixel-04-03-2021_16-43-50.json",
"p3_5-pixel-04-03-2021_17-11-32.json",
"p3_6-pixel-17-03-2021_12-52-29.json",
"p3_7-pixel-17-03-2021_13-14-36.json"]

# Redmi
etaje_0_r = ["p0_0-redmi-04-03-2021_15-31-12.json",
"p0_1-redmi-25-02-2021_21-16-10.json",
"p0_2-redmi-25-02-2021_16-27-08.json",
"p0_3-redmi-04-03-2021_16-18-52.json",
"p0_4-redmi-04-03-2021_16-43-45.json",
"p0_5-redmi-04-03-2021_17-11-30.json",
"p0_6-redmi-17-03-2021_12-52-29.json",
"p0_7-redmi-17-03-2021_13-14-39.json"]

etaje_1_r = ["p1_0-redmi-04-03-2021_15-31-12.json",
"p1_1-redmi-25-02-2021_21-16-10.json",
"p1_2-redmi-25-02-2021_16-27-08.json",
"p1_3-redmi-04-03-2021_16-18-52.json",
"p1_4-redmi-04-03-2021_16-43-45.json",
"p1_5-redmi-04-03-2021_17-11-30.json",
"p1_6-redmi-17-03-2021_12-52-29.json",
"p1_7-redmi-17-03-2021_13-14-39.json"]
       
            
etaje_2_r = ["p2_0-redmi-04-03-2021_15-31-12.json",
"p2_1-redmi-25-02-2021_21-16-10.json",
"p2_2-redmi-25-02-2021_16-27-08.json",
"p2_3-redmi-04-03-2021_16-18-52.json",
"p2_4-redmi-04-03-2021_16-43-45.json",
"p2_5-redmi-04-03-2021_17-11-30.json",
"p2_6-redmi-17-03-2021_12-52-29.json",
"p2_7-redmi-17-03-2021_13-14-39.json"]
     

etaje_3_r = ["p3_0-redmi-04-03-2021_15-31-12.json",
"p3_1-redmi-25-02-2021_21-16-10.json",
"p3_2-redmi-25-02-2021_16-27-08.json",
"p3_3-redmi-04-03-2021_16-18-52.json",
"p3_4-redmi-04-03-2021_16-43-45.json",
"p3_5-redmi-04-03-2021_17-11-30.json",
"p3_6-redmi-17-03-2021_12-52-29.json",
"p3_7-redmi-17-03-2021_13-14-39.json"]
     

similarity_methods = [cosine, cityblock, euclidean, braycurtis]
#similarity_methods = [cosine, braycurtis, euclidean, cityblock, jaccard]
list_d_nearest = []

for m in similarity_methods:
    d_nearest = []
    collections = []

# Modify etaje_X:
    for e in etaje_3_p: 
        json_file = os.path.join(datadir, e)
        collection = load_dataset_json(json_file)
        collections.append(collection)

        d_nearest = d_nearest + test_allvsall(collection, m)


    
    list_d_nearest.append(d_nearest)



# points from all collections

# %%
import scipy


for d_near in list_d_nearest:
    nearest = np.array(d_near)

    away = nearest[:, 3] # steps away from true 
    b = np.arange(1, 14, 1) # Bins of histogram - from 1 to 5 
    bin_width = b[1] - b[0]

    hist_away, bins_out = np.histogram(away, b, density=False)

    hist_away = hist_away / away.size

    fig = plt.figure()
    plt.bar(b[:-1], hist_away, width=bin_width, ec='k', alpha=0.8)
    plt.xlabel("Steps away from true location")
    plt.ylabel("PMF")
    plt.title("{}\n{}{}\n{}{}".format("Distribution across ", len(d_nearest), " points; Average across RSSI N/E/S/W", 
                                 'for method ', similarity_methods[list_d_nearest.index(d_near)].__name__))

    plt.tight_layout()
    #fig.savefig(os.path.join(save_img_dir, fn))
    plt.show()
    
    cdf=np.cumsum(hist_away)
    plt.axhline(y=1, color='r', linestyle='--')
    plt.xlabel("Steps away from true location")
    plt.ylabel("CDF(%)")
    plt.title("{}{}".format("CDF for method ", similarity_methods[list_d_nearest.index(d_near)].__name__))
    plt.plot(b[:len(hist_away)], cdf)
    
    
    print("Percentages: ", hist_away)
# Out:
# Percentages:  [0.71618037 0.21750663 0.03448276 0.02917772 0.         0.
#  0.00265252 0.         0.         0.         0.         0.        ]
# Percentages:  [0.76127321 0.18567639 0.03183024 0.01591512 0.00265252 0.
#  0.00265252 0.         0.         0.         0.         0.        ]
# Percentages:  [0.72679045 0.20159151 0.04774536 0.02122016 0.00265252 0.
#  0.         0.         0.         0.         0.         0.        ]
# Percentages:  [0.77188329 0.18302387 0.02917772 0.01591512 0.         0.
#  0.         0.         0.         0.         0.         0.        ]

# %%
nearest = np.array(list_d_nearest[3]) #braycurtis
bad_pts = nearest[away == 2]
print(bad_pts)
dists = bad_pts[:, 3] # steps away from true
# Out:
# [[1.10000000e+01 1.30000000e+01 1.41564963e-01 2.00000000e+00
#   1.62486529e-01]
#  [2.90000000e+01 3.10000000e+01 9.95145226e-02 2.00000000e+00
#   1.06899726e-01]
#  [3.00000000e+01 2.80000000e+01 1.50152876e-01 2.00000000e+00
#   1.79367340e-01]
#  [3.10000000e+01 2.90000000e+01 9.95145226e-02 2.00000000e+00
#   1.43615827e-01]
#  [3.30000000e+01 3.50000000e+01 1.13160469e-01 2.00000000e+00
#   1.33468684e-01]
#  [3.50000000e+01 3.30000000e+01 1.13160469e-01 2.00000000e+00
#   1.29920206e-01]
#  [4.30000000e+01 4.50000000e+01 1.33286263e-01 2.00000000e+00
#   1.44523587e-01]
#  [0.00000000e+00 4.70000000e+01 8.19953868e-02 2.00000000e+00
#   1.13952112e-01]
#  [8.00000000e+00 1.00000000e+01 1.07478036e-01 2.00000000e+00
#   1.12209191e-01]
#  [9.00000000e+00 1.10000000e+01 9.50866722e-02 2.00000000e+00
#   1.15211616e-01]
#  [1.00000000e+01 8.00000000e+00 1.07478036e-01 2.00000000e+00
#   1.48092239e-01]
#  [1.10000000e+01 9.00000000e+00 9.50866722e-02 2.00000000e+00
# ...

# %%
for d_near in list_d_nearest:
    nearest = np.array(d_near)
    good_pts = nearest[away <= 3]
    dists = good_pts[:, 2] # steps away from true 
    b = np.arange(0, 0.3, 0.01) # Bins of histogram - from 1 to 5 
    bin_width = b[1] - b[0]

    hist_away, bins_out = np.histogram(dists, b, density=False)

    hist_away = hist_away / away.size

    fig = plt.figure()
    plt.bar(b[:-1], hist_away, width=bin_width, ec='k', alpha=0.8)
    plt.xlabel("Steps away from true location")
    plt.ylabel("PMF")
    plt.title("{}\n{}{}\n{}{}".format("Distribution of distances across ", len(dists),
                                    " good points (closest is 1 step away)",
                                    " for method ", similarity_methods[list_d_nearest.index(d_near)].__name__))



    plt.tight_layout()
    #fig.savefig(os.path.join(save_img_dir, fn))
    plt.show()
    print("Mean Std =", np.mean(dists), np.std(dists))
# Out:
# Mean Std = 0.0112965545096683 0.0090091787765547
# Mean Std = 0.08861137161427748 0.04167012130434306
# Mean Std = 0.0384147932490442 0.016577320610451068
# Mean Std = 0.08598930157266091 0.02843556286988863

# %%
# Method = Tempered

list_d_nearest = []

for m in similarity_methods:
    d_nearest = []
    collections = []


    for e in etaje_0: 
        json_file = os.path.join(datadir, e)
        collection = load_dataset_json(json_file)
        collections.append(collection)

        d_nearest = d_nearest + test_allvsall(collection, m, method = 'Tempered')


    
    list_d_nearest.append(d_nearest)


for d_near in list_d_nearest:
    nearest = np.array(d_near)

    away = nearest[:, 3] # steps away from true 
    b = np.arange(1, 6, 1) # Bins of histogram - from 1 to 5 
    bin_width = b[1] - b[0]

    hist_away, bins_out = np.histogram(away, b, density=False)

    hist_away = hist_away / away.size

    fig = plt.figure()
    plt.bar(b[:-1], hist_away, width=bin_width, ec='k', alpha=0.8)
    plt.xlabel("Steps away from true location")
    plt.ylabel("PMF")
    plt.title("{}\n{}{}\n{}{}".format("Distribution across ", len(d_nearest), " points; Average across RSSI N/E/S/W", 
                                 'for method ', similarity_methods[list_d_nearest.index(d_near)].__name__))

    plt.tight_layout()
    #fig.savefig(os.path.join(save_img_dir, fn))
    plt.show()
    print("Percentages: ", hist_away)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-70a507b84aff> in <module>
#       8
#       9
# ---> 10     for e in etaje_0:
#      11         json_file = os.path.join(datadir, e)
#      12         collection = load_dataset_json(json_file)
#
# NameError: name 'etaje_0' is not defined

# %%
#Let's take a look at the 'wrong' locations
np.array(list_d_nearest[4]) #braycurtis
good_pts = nearest[away == 1]
not_so_good_pts = nearest[away == 2]
#print(good_pts[:, 2])
#print(not_so_good_pts[:, 2])

# %%
# TODO count number of common APs
